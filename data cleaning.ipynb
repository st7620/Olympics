# %%
# Import libraries for data preprocessing
import numpy as np
import pandas as pd

# %%
years = [1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016, 2020]

# %%
# Load population data
df_population = pd.read_csv("Datasets\\Demographics\\2a369fff-08eb-4ed9-adce-92957698ad90_Data.csv", skiprows=range(218,272))

# Drop columns we don't need
print(df_population.columns)
columns_to_drop = ['Series Name', 'Series Code', 'Country Code']
df_population = df_population.drop(columns=columns_to_drop)

# Estimate the population for 2024
df_population['2024'] = df_population['2023 [YR2023]']*1.091
df_population['2024'] = df_population['2024'].apply(lambda x: int(x))
df_population = df_population.drop(columns=['2023 [YR2023]'])
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code',
#        '1980 [YR1980]', '1984 [YR1984]', '1988 [YR1988]', '1992 [YR1992]',
#        '1996 [YR1996]', '2000 [YR2000]', '2004 [YR2004]', '2008 [YR2008]',
#        '2012 [YR2012]', '2016 [YR2016]', '2020 [YR2020]', '2023 [YR2023]'],
#       dtype='object')

# %%
# Transpose the data to match the format of the other dataset
df_population_transposed = df_population.melt(id_vars=['Country Name'], var_name='Year', value_name='Population')

# Check if there are missing values
df_population_transposed = df_population_transposed.replace('..', np.nan)
df_population_transposed = df_population_transposed.dropna()
print(df_population_transposed.isnull().sum())

# Convert strings to numerical values
df_population_transposed['Year'] = df_population_transposed['Year'].str.extract(r'(\d+)')
df_population_transposed["Year"] = df_population_transposed["Year"].apply(lambda x: int(x))
df_population_transposed["Population"] = df_population_transposed["Population"].apply(lambda x: float(x))

# Sort the data by country and year
df_population_transposed = df_population_transposed.sort_values(by = ['Country Name', 'Year'], ascending=[True, True])

# Rename columns to match the other dataset
df_population_transposed = df_population_transposed.rename(columns={'Country Name': 'Country'})

# Save cleaned file
df_population_transposed.to_csv('Datasets\\Demographics\\Cleaned\\WB_Population.csv', index=False)
# Out:
# Country Name    0
# Year            0
# Population      0
# dtype: int64

# %%
# Load GDP data
df_gdp = pd.read_csv("Datasets\\Demographics\\WEO_Data.xls", delimiter="\t", encoding="UTF-16 LE")

# Keep only the columns we need
print(df_gdp.columns)
columns_to_keep = [str(year) for year in years]
columns_to_keep.insert(0,'Country')
columns_to_keep.append("2024")
df_gdp = df_gdp[columns_to_keep]

# Fill in missing values
df_gdp = df_gdp.fillna(value=0, axis=1)

# Drop rows with missing values
df_gdp = df_gdp.replace('--', np.nan)
df_gdp = df_gdp.dropna()
# Out:
# Index(['Country', 'Subject Descriptor', 'Units', 'Scale',
#        'Country/Series-specific Notes', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022', '2023', '2024', 'Estimates Start After', 'Unnamed: 51'],
#       dtype='object')

# %%
# Transpose the data to match the format of the other dataset
df_gdp_transposed = df_gdp.melt(id_vars='Country', var_name='Year', value_name='GDP_share')

# Convert strings to numerical values
df_gdp_transposed["Year"] = df_gdp_transposed["Year"].apply(lambda x: int(x))
df_gdp_transposed["GDP_share"] = df_gdp_transposed["GDP_share"].apply(lambda x: float(x))

# Check if there are missing values
print(df_gdp_transposed.isnull().sum())

# Sort the data by country and year
df_gdp_transposed = df_gdp_transposed.sort_values(by = ['Country', 'Year'], ascending=[True, True])

# Save cleaned file
df_gdp_transposed.to_csv('Datasets\\Demographics\\Cleaned\\WEO_GDP.csv', index=False)
# Out:
# Country      0
# Year         0
# GDP_share    0
# dtype: int64

# %%
# Load medals data
df_medals = pd.read_csv("Datasets\\Historical\\Olympic_Games_Medal_Tally.csv")

# Filter for summer games and years we need
df_medals = df_medals.loc[df_medals["year"].isin(years)]
df_medals = df_medals.loc[df_medals["edition"].str.contains("Summer")]

# Drop columns we don't need
cols_to_drop = ["edition_id", "edition", "country_noc"]
df_medals = df_medals.drop(columns=cols_to_drop)

# %%
# Merge gpd and population dataframes
df_merged = pd.merge(df_gdp_transposed, df_population_transposed, on=['Country', 'Year'], how='inner')

# Create new rows for missing years
for country in df_merged.Country.unique():
    for year in years:
        if not ((df_medals['country'] == country) & (df_medals['year'] == year)).any():
            new_row = {'year': year, 'country': country, 'gold': 0, 'silver': 0, 'bronze': 0, 'total': 0}
            df_medals = df_medals._append(new_row, ignore_index=True)

# Sort the data by country and year
df_medals = df_medals.sort_values(by = ['country', 'year'], ascending=[True, True])

# Rename columns to match the other dataset
df_medals = df_medals.rename(columns={'country': 'Country', 'year': 'Year'})

# Join medals and merged dataframes and fill in missing values
df_concat = pd.merge(df_merged, df_medals, on=['Country', 'Year'], how='inner')

# %%
import requests
from bs4 import BeautifulSoup

def get_number_of_athletes(country_name):

    # List of years for the Summer Olympics Wikipedia pages
    years = [1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016, 2020, 2024]

    # Dictionary to store the number of athletes for each country
    athletes_data = dict.fromkeys(years)

    # Iterate over the years
    for year in years:
        # Construct the URL
        url = f"https://en.wikipedia.org/wiki/{year}_Summer_Olympics"

        # Send a request to the URL
        response = requests.get(url)
    
        # Check if the request was successful
        if response.status_code != 200:
            print(f"Failed to retrieve the page. Status code: {response.status_code}")
            return None
        
        # Parse the content of the request with BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find the table with the participating National Olympic Committees
        if year in [1988, 1992]:
            table = soup.find('table', {'class': 'wikitable sortable'})
        elif year == 1980:
            table = soup.find('table', {'class': 'wikitable collapsible collapsed sortable'})
        elif year == 2012:
            table = soup.find('table', {'class': 'wikitable mw-collapsible mw-collapsed sortable'})
        else:
            table = soup.find('table', {'class': 'wikitable collapsible collapsed sortable'})
        
        if not table:
            print(f"Failed to find the table for {year}.")
            return None
        
        # Extract table rows
        rows = table.find_all('tr')
        
        # Iterate over rows to find the country
        for row in rows[1:]:  # Skip the header row
            cols = row.find_all('td')
            if cols:
                country = cols[1].text.strip()
                if country_name.lower() in country.lower():
                    number_of_athletes = cols[-1].text.strip()
                    athletes_data[year] = number_of_athletes
                    break
    
    # Check if the dictionary is empty
    if all(value == None for value in athletes_data.values()):
        print(f"Failed to find the number of athletes for {country_name}.")
        return None
    # Check if there are missing values and replace with 0
    elif any(value == None for value in athletes_data.values()):
        athletes_data = {year: 0 if value is None else value for year, value in athletes_data.items()}
        print(f"Failed to find the number of athletes for some years for {country_name}.")
    
    # Convert the dictionary to a DataFrame
    df = pd.DataFrame.from_dict(athletes_data, orient='index', columns=['Number of Athletes'])
    df = df.reset_index().rename(columns={'index': 'Year'})
    country_series = pd.Series([country_name] * len(df), name='Country')
    df = pd.concat([country_series, df], axis=1)
    
    return df

# %%
# Get the number of athletes for each country
countries = df_concat['Country'].unique()
df_athletes_all = None
for country in countries:
    print(f"Getting the number of athletes for {country}.")
    df_athletes = get_number_of_athletes(country)
    if df_athletes is not None:
        if country == countries[0]:
            df_athletes_all = df_athletes
        else:
            df_athletes_all = pd.concat([df_athletes_all, df_athletes])
df_athletes_all.to_csv('Datasets\\Demographics\\Cleaned\\Number_of_Athletes.csv', index=False)
# Out:
# Getting the number of athletes for Afghanistan.
# Failed to find the number of athletes for some years for Afghanistan.
# Getting the number of athletes for Albania.
# Failed to find the number of athletes for some years for Albania.
# Getting the number of athletes for Algeria.
# Getting the number of athletes for Andorra.
# Getting the number of athletes for Angola.
# Failed to find the number of athletes for some years for Angola.
# Getting the number of athletes for Antigua and Barbuda.
# Failed to find the number of athletes for some years for Antigua and Barbuda.
# Getting the number of athletes for Argentina.
# Failed to find the number of athletes for some years for Argentina.
# Getting the number of athletes for Armenia.
# Failed to find the number of athletes for some years for Armenia.
# Getting the number of athletes for Aruba.
# Failed to find the number of athletes for some years for Aruba.
# Getting the number of athletes for Australia.
# Getting the number of athletes for Austria.
# Getting the number of athletes for Azerbaijan.
# Failed to find the number of athletes for some years for Azerbaijan.
# Getting the number of athletes for Bahrain.
# Failed to find the number of athletes for some years for Bahrain.
# Getting the number of athletes for Bangladesh.
# Failed to find the number of athletes for some years for Bangladesh.
# Getting the number of athletes for Barbados.
# Failed to find the number of athletes for some years for Barbados.
# Getting the number of athletes for Belarus.
# Failed to find the number of athletes for some years for Belarus.
# Getting the number of athletes for Belgium.
# Getting the number of athletes for Belize.
# Failed to find the number of athletes for some years for Belize.
# Getting the number of athletes for Benin.
# Getting the number of athletes for Bhutan.
# Failed to find the number of athletes for some years for Bhutan.
# Getting the number of athletes for Bolivia.
# Failed to find the number of athletes for some years for Bolivia.
# Getting the number of athletes for Bosnia and Herzegovina.
# Failed to find the number of athletes for some years for Bosnia and Herzegovina.
# Getting the number of athletes for Botswana.
# Getting the number of athletes for Brazil.
# Getting the number of athletes for Brunei Darussalam.
# Failed to find the number of athletes for Brunei Darussalam.
# Getting the number of athletes for Bulgaria.
# Failed to find the number of athletes for some years for Bulgaria.
# Getting the number of athletes for Burkina Faso.
# Failed to find the number of athletes for some years for Burkina Faso.
# Getting the number of athletes for Burundi.
# Failed to find the number of athletes for some years for Burundi.
# Getting the number of athletes for Cabo Verde.
# Failed to find the number of athletes for Cabo Verde.
# Getting the number of athletes for Cambodia.
# Failed to find the number of athletes for some years for Cambodia.
# Getting the number of athletes for Cameroon.
# Getting the number of athletes for Canada.
# Failed to find the number of athletes for some years for Canada.
# Getting the number of athletes for Central African Republic.
# Failed to find the number of athletes for some years for Central African Republic.
# Getting the number of athletes for Chad.
# Failed to find the number of athletes for some years for Chad.
# Getting the number of athletes for Chile.
# Failed to find the number of athletes for some years for Chile.
# Getting the number of athletes for China.
# Failed to find the number of athletes for some years for China.
# Getting the number of athletes for Colombia.
# Getting the number of athletes for Comoros.
# Failed to find the number of athletes for some years for Comoros.
# Getting the number of athletes for Costa Rica.
# Getting the number of athletes for Croatia.
# Failed to find the number of athletes for some years for Croatia.
# Getting the number of athletes for Cyprus.
# Getting the number of athletes for Denmark.
# Getting the number of athletes for Djibouti.
# Failed to find the number of athletes for some years for Djibouti.
# Getting the number of athletes for Dominica.
# Getting the number of athletes for Dominican Republic.
# Getting the number of athletes for Ecuador.
# Getting the number of athletes for El Salvador.
# Failed to find the number of athletes for some years for El Salvador.
# Getting the number of athletes for Equatorial Guinea.
# Failed to find the number of athletes for some years for Equatorial Guinea.
# Getting the number of athletes for Eritrea.
# Failed to find the number of athletes for some years for Eritrea.
# Getting the number of athletes for Estonia.
# Failed to find the number of athletes for some years for Estonia.
# Getting the number of athletes for Eswatini.
# Failed to find the number of athletes for some years for Eswatini.
# Getting the number of athletes for Ethiopia.
# Failed to find the number of athletes for some years for Ethiopia.
# Getting the number of athletes for Fiji.
# Failed to find the number of athletes for some years for Fiji.
# Getting the number of athletes for Finland.
# Getting the number of athletes for France.
# Getting the number of athletes for Gabon.
# Failed to find the number of athletes for some years for Gabon.
# Getting the number of athletes for Georgia.
# Failed to find the number of athletes for some years for Georgia.
# Getting the number of athletes for Germany.
# Getting the number of athletes for Ghana.
# Failed to find the number of athletes for some years for Ghana.
# Getting the number of athletes for Greece.
# Getting the number of athletes for Grenada.
# Failed to find the number of athletes for some years for Grenada.
# Getting the number of athletes for Guatemala.
# Getting the number of athletes for Guinea.
# Getting the number of athletes for Guinea-Bissau.
# Failed to find the number of athletes for some years for Guinea-Bissau.
# Getting the number of athletes for Guyana.
# Getting the number of athletes for Haiti.
# Failed to find the number of athletes for some years for Haiti.
# Getting the number of athletes for Honduras.
# Failed to find the number of athletes for some years for Honduras.
# Getting the number of athletes for Hungary.
# Failed to find the number of athletes for some years for Hungary.
# Getting the number of athletes for Iceland.
# Getting the number of athletes for India.
# Getting the number of athletes for Indonesia.
# Failed to find the number of athletes for some years for Indonesia.
# Getting the number of athletes for Iraq.
# Getting the number of athletes for Ireland.
# Getting the number of athletes for Israel.
# Failed to find the number of athletes for some years for Israel.
# Getting the number of athletes for Italy.
# Failed to find the number of athletes for some years for Italy.
# Getting the number of athletes for Jamaica.
# Getting the number of athletes for Japan.
# Failed to find the number of athletes for some years for Japan.
# Getting the number of athletes for Jordan.
# Getting the number of athletes for Kazakhstan.
# Failed to find the number of athletes for some years for Kazakhstan.
# Getting the number of athletes for Kenya.
# Failed to find the number of athletes for some years for Kenya.
# Getting the number of athletes for Kosovo.
# Failed to find the number of athletes for some years for Kosovo.
# Getting the number of athletes for Kuwait.
# Failed to find the number of athletes for some years for Kuwait.
# Getting the number of athletes for Kyrgyz Republic.
# Failed to find the number of athletes for Kyrgyz Republic.
# Getting the number of athletes for Latvia.
# Failed to find the number of athletes for some years for Latvia.
# Getting the number of athletes for Lebanon.
# Getting the number of athletes for Lesotho.
# Getting the number of athletes for Liberia.
# Failed to find the number of athletes for some years for Liberia.
# Getting the number of athletes for Libya.
# Failed to find the number of athletes for some years for Libya.
# Getting the number of athletes for Lithuania.
# Failed to find the number of athletes for some years for Lithuania.
# Getting the number of athletes for Luxembourg.
# Getting the number of athletes for Madagascar.
# Failed to find the number of athletes for some years for Madagascar.
# Getting the number of athletes for Malawi.
# Failed to find the number of athletes for some years for Malawi.
# Getting the number of athletes for Malaysia.
# Failed to find the number of athletes for some years for Malaysia.
# Getting the number of athletes for Maldives.
# Failed to find the number of athletes for some years for Maldives.
# Getting the number of athletes for Mali.
# Getting the number of athletes for Malta.
# Getting the number of athletes for Mauritania.
# Failed to find the number of athletes for some years for Mauritania.
# Getting the number of athletes for Mauritius.
# Failed to find the number of athletes for some years for Mauritius.
# Getting the number of athletes for Mexico.
# Getting the number of athletes for Moldova.
# Failed to find the number of athletes for some years for Moldova.
# Getting the number of athletes for Mongolia.
# Failed to find the number of athletes for some years for Mongolia.
# Getting the number of athletes for Montenegro.
# Failed to find the number of athletes for some years for Montenegro.
# Getting the number of athletes for Morocco.
# Failed to find the number of athletes for some years for Morocco.
# Getting the number of athletes for Mozambique.
# Getting the number of athletes for Myanmar.
# Failed to find the number of athletes for some years for Myanmar.
# Getting the number of athletes for Namibia.
# Failed to find the number of athletes for some years for Namibia.
# Getting the number of athletes for Nepal.
# Getting the number of athletes for Netherlands.
# Getting the number of athletes for New Zealand.
# Getting the number of athletes for Nicaragua.
# Failed to find the number of athletes for some years for Nicaragua.
# Getting the number of athletes for Niger.
# Getting the number of athletes for Nigeria.
# Getting the number of athletes for North Macedonia.
# Failed to find the number of athletes for some years for North Macedonia.
# Getting the number of athletes for Norway.
# Failed to find the number of athletes for some years for Norway.
# Getting the number of athletes for Oman.
# Getting the number of athletes for Pakistan.
# Failed to find the number of athletes for some years for Pakistan.
# Getting the number of athletes for Panama.
# Failed to find the number of athletes for some years for Panama.
# Getting the number of athletes for Papua New Guinea.
# Failed to find the number of athletes for some years for Papua New Guinea.
# Getting the number of athletes for Paraguay.
# Failed to find the number of athletes for some years for Paraguay.
# Getting the number of athletes for Peru.
# Getting the number of athletes for Philippines.
# Failed to find the number of athletes for some years for Philippines.
# Getting the number of athletes for Poland.
# Failed to find the number of athletes for some years for Poland.
# Getting the number of athletes for Portugal.
# Getting the number of athletes for Puerto Rico.
# Getting the number of athletes for Qatar.
# Failed to find the number of athletes for some years for Qatar.
# Getting the number of athletes for Romania.
# Getting the number of athletes for Rwanda.
# Failed to find the number of athletes for some years for Rwanda.
# Getting the number of athletes for Samoa.
# Failed to find the number of athletes for some years for Samoa.
# Getting the number of athletes for San Marino.
# Getting the number of athletes for Saudi Arabia.
# Failed to find the number of athletes for some years for Saudi Arabia.
# Getting the number of athletes for Senegal.
# Getting the number of athletes for Serbia.
# Failed to find the number of athletes for some years for Serbia.
# Getting the number of athletes for Seychelles.
# Failed to find the number of athletes for some years for Seychelles.
# Getting the number of athletes for Sierra Leone.
# Getting the number of athletes for Singapore.
# Failed to find the number of athletes for some years for Singapore.
# Getting the number of athletes for Slovak Republic.
# Failed to find the number of athletes for Slovak Republic.
# Getting the number of athletes for Slovenia.
# Failed to find the number of athletes for some years for Slovenia.
# Getting the number of athletes for Solomon Islands.
# Failed to find the number of athletes for some years for Solomon Islands.
# Getting the number of athletes for Somalia.
# Failed to find the number of athletes for some years for Somalia.
# Getting the number of athletes for South Africa.
# Failed to find the number of athletes for some years for South Africa.
# Getting the number of athletes for South Sudan.
# Failed to find the number of athletes for some years for South Sudan.
# Getting the number of athletes for Spain.
# Getting the number of athletes for Sri Lanka.
# Getting the number of athletes for St. Kitts and Nevis.
# Failed to find the number of athletes for St. Kitts and Nevis.
# Getting the number of athletes for St. Lucia.
# Failed to find the number of athletes for St. Lucia.
# Getting the number of athletes for St. Vincent and the Grenadines.
# Failed to find the number of athletes for St. Vincent and the Grenadines.
# Getting the number of athletes for Sudan.
# Failed to find the number of athletes for some years for Sudan.
# Getting the number of athletes for Suriname.
# Failed to find the number of athletes for some years for Suriname.
# Getting the number of athletes for Sweden.
# Getting the number of athletes for Switzerland.
# Getting the number of athletes for Tajikistan.
# Failed to find the number of athletes for some years for Tajikistan.
# Getting the number of athletes for Tanzania.
# Getting the number of athletes for Thailand.
# Failed to find the number of athletes for some years for Thailand.
# Getting the number of athletes for Timor-Leste.
# Failed to find the number of athletes for Timor-Leste.
# Getting the number of athletes for Togo.
# Failed to find the number of athletes for some years for Togo.
# Getting the number of athletes for Trinidad and Tobago.
# Getting the number of athletes for Tunisia.
# Failed to find the number of athletes for some years for Tunisia.
# Getting the number of athletes for Turkmenistan.
# Failed to find the number of athletes for some years for Turkmenistan.
# Getting the number of athletes for Uganda.
# Getting the number of athletes for Ukraine.
# Failed to find the number of athletes for some years for Ukraine.
# Getting the number of athletes for United Arab Emirates.
# Failed to find the number of athletes for some years for United Arab Emirates.
# Getting the number of athletes for United Kingdom.
# Failed to find the number of athletes for United Kingdom.
# Getting the number of athletes for United States.
# Failed to find the number of athletes for some years for United States.
# Getting the number of athletes for Uruguay.
# Failed to find the number of athletes for some years for Uruguay.
# Getting the number of athletes for Uzbekistan.
# Failed to find the number of athletes for some years for Uzbekistan.
# Getting the number of athletes for Vanuatu.
# Failed to find the number of athletes for some years for Vanuatu.
# Getting the number of athletes for West Bank and Gaza.
# Failed to find the number of athletes for West Bank and Gaza.
# Getting the number of athletes for Zambia.
# Getting the number of athletes for Zimbabwe.

# %%
# Load the number of athletes data
df_athletes_all = pd.read_csv("Datasets\\Demographics\\Cleaned\\Number_of_Athletes.csv")

# Rename columns for merging
# df_athletes_all.rename(columns={'Country': 'c', 'Year': 'y'}, inplace=True)

# Merge the dataframes
df_concat = df_concat[df_concat['Country'].isin(df_athletes_all['Country'])]
df_full = pd.merge(df_concat, df_athletes_all, on=['Country', 'Year'], how='inner')

# Convert the year to datetime
year_dt = pd.to_datetime(df_full["Year"], format='%Y')
df_full.drop(columns=["Year"], inplace=True)
df_full = df_full.join(year_dt)

# Save the final dataset
df_full.to_csv('Datasets\\final.csv', index=False)
